# %% [markdown]
# Scraping Exercises

# %% [markdown]
# Scrape the following into CSV files. Each one is broken up into multiple tiers – the more you scrape the tougher it is!

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import re
import numpy as np
import time
import os

# %% [markdown]
# # Congress members
# Scrape https://www.congress.gov/members (Links to an external site.)
# <li>Tier 1: Scrape their name and full profile URL, and additional</li>
# <li>Tier 2: Separate their state/party/etc into separate columns</li>
# <li>Advanced: Scrape each person's actual data from their personal project</li>

# %%
members = []

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}

# %% [markdown]
# ## Tier 1: Scrape their name and full profile URL, and additional
# ## Tier 2: Separate their state/party/etc into separate columns

# %%
#url
#10 pages for 2,429 members
for page in np.arange(1,11):
    url = f'https://www.congress.gov/members?pageSize=250&page={page}'
    
    #get raw data
    response = response = requests.get(url, headers=headers)
    doc = bs(response.content)

    for tag in doc.select("li.compact"):
        #name, url
        element = tag.find("a", href=True)
        name = element.text
        profile_url = element["href"]
        profile_url = ('https://www.congress.gov' + profile_url) if "http" not in profile_url else profile_url
        
        #other items
        state = tag.find(text=re.compile(".*State:.*")).next.next.text
        party = tag.find(text="Party:").next.next.text
        served = tag.find(text="Served:").next.next.text
        try:
            district = tag.find(text="District:").next.next.text
        except:
            district = np.nan
        
        #dictionary of data for a congress person
        data ={
            "name": name,
            "url" : profile_url,
            "state" : state,
            "district" : district,
            "party" : party,
            "served" : served
        }
    
        members.append(data)

    time.sleep(1)
members_df = pd.DataFrame(members)

# %%
members_df.served = members_df.served.str.replace("\n","")

# %%
members_df["senate"] = members_df.served.str.extract(".*Senate: (\d\d\d\d\-\d\d\d\d)")
members_df["house"] = members_df.served.str.extract(".*House: (\d\d\d\d\-\d\d\d\d)")

# %%
members_df
# Out:
#                                     name  \
# 0                  Senator Abdnor, James
# 1       Representative Abercrombie, Neil
# 2                Senator Abourezk, James
# 3      Representative Abraham, Ralph Lee
# 4               Senator Abraham, Spencer
# ...                                  ...
# 2424       Representative Zinke, Ryan K.
# 2425       Representative Zion, Roger H.
# 2426            Senator Zorinsky, Edward
# 2427  Representative Zschau, Edwin V. W.
# 2428       Representative Zwach, John M.
#
#                                                     url         state  \
# 0     https://www.congress.gov/member/james-abdnor/A...  South Dakota
# 1     https://www.congress.gov/member/neil-abercromb...        Hawaii
# 2     https://www.congress.gov/member/james-abourezk...  South Dakota
# 3     https://www.congress.gov/member/ralph-abraham/...     Louisiana
# 4     https://www.congress.gov/member/spencer-abraha...      Michigan
# ...                                                 ...           ...
# 2424  https://www.congress.gov/member/ryan-zinke/Z00...       Montana
# 2425  https://www.congress.gov/member/roger-zion/Z00...       Indiana
# 2426  https://www.congress.gov/member/edward-zorinsk...      Nebraska
# 2427  https://www.congress.gov/member/edwin-zschau/Z...    California
# 2428  https://www.congress.gov/member/john-zwach/Z00...     Minnesota
#
#       district       party                               served     senate  \
# 0          NaN  Republican  Senate: 1981-1987 House: 1973-1981   1981-1987
# 1            1  Democratic         House: 1985-1987, 1991-2011         NaN
# 2          NaN  Democratic  Senate: 1973-1979 House: 1971-1973   1973-1979
# 3            5  Republican                    House: 2015-2021         NaN
# 4          NaN  Republican                   Senate: 1995-2001   1995-2001
# ...        ...         ...                                  ...        ...
# 2424  At Large  Republican                    House: 2015-2017         NaN
# 2425         8  Republican                    House: 1967-1975         NaN
# 2426       NaN  Democratic                   Senate: 1977-1989   1977-1989
# 2427        12  Republican                    House: 1983-1987         NaN
# 2428         6  Republican                    House: 1967-1975         NaN
#
#           house
# 0     1973-1981
# 1     1985-1987
# 2     1971-1973
# 3     2015-2021
# 4           NaN
# ...         ...
# 2424  2015-2017
# 2425  1967-1975
# 2426        NaN
# 2427  1983-1987
# 2428  1967-1975
#
# [2429 rows x 8 columns]

# %% [markdown]
# ## Advanced: Scrape each person's actual data from their personal project

# %%
#I'm getting banned repeatedly...

#for i in range(len(members_df)):
#    result_list = []
#    get_actual_data = True
#    url = members_df.url[i]
#    page =1
#    
#    while get_actual_data:
#        try:
#            personal_url = f"{url}?pageSize=250&page={page}"
#            response = requests.get(personal_url)
#            doc = bs(response.content)
#            results = doc.select(".result-title")
#            result_list = result_list + [result.text for result in results]
#            
#            page+=1
#        except:
#            get_actual_data = False
#    
#    members_df.loc[i, 'results'] = result_list
#    time.sleep(1)

# %%
members_df
# Out:
#                                     name  \
# 0                  Senator Abdnor, James
# 1       Representative Abercrombie, Neil
# 2                Senator Abourezk, James
# 3      Representative Abraham, Ralph Lee
# 4               Senator Abraham, Spencer
# ...                                  ...
# 2424       Representative Zinke, Ryan K.
# 2425       Representative Zion, Roger H.
# 2426            Senator Zorinsky, Edward
# 2427  Representative Zschau, Edwin V. W.
# 2428       Representative Zwach, John M.
#
#                                                     url         state  \
# 0     https://www.congress.gov/member/james-abdnor/A...  South Dakota
# 1     https://www.congress.gov/member/neil-abercromb...        Hawaii
# 2     https://www.congress.gov/member/james-abourezk...  South Dakota
# 3     https://www.congress.gov/member/ralph-abraham/...     Louisiana
# 4     https://www.congress.gov/member/spencer-abraha...      Michigan
# ...                                                 ...           ...
# 2424  https://www.congress.gov/member/ryan-zinke/Z00...       Montana
# 2425  https://www.congress.gov/member/roger-zion/Z00...       Indiana
# 2426  https://www.congress.gov/member/edward-zorinsk...      Nebraska
# 2427  https://www.congress.gov/member/edwin-zschau/Z...    California
# 2428  https://www.congress.gov/member/john-zwach/Z00...     Minnesota
#
#       district       party                               served     senate  \
# 0          NaN  Republican  Senate: 1981-1987 House: 1973-1981   1981-1987
# 1            1  Democratic         House: 1985-1987, 1991-2011         NaN
# 2          NaN  Democratic  Senate: 1973-1979 House: 1971-1973   1973-1979
# 3            5  Republican                    House: 2015-2021         NaN
# 4          NaN  Republican                   Senate: 1995-2001   1995-2001
# ...        ...         ...                                  ...        ...
# 2424  At Large  Republican                    House: 2015-2017         NaN
# 2425         8  Republican                    House: 1967-1975         NaN
# 2426       NaN  Democratic                   Senate: 1977-1989   1977-1989
# 2427        12  Republican                    House: 1983-1987         NaN
# 2428         6  Republican                    House: 1967-1975         NaN
#
#           house  results
# 0     1973-1981      NaN
# 1     1985-1987      NaN
# 2     1971-1973      NaN
# 3     2015-2021      NaN
# 4           NaN      NaN
# ...         ...      ...
# 2424  2015-2017      NaN
# 2425  1967-1975      NaN
# 2426        NaN      NaN
# 2427  1983-1987      NaN
# 2428  1967-1975      NaN
#
# [2429 rows x 9 columns]

# %% [markdown]
# # Maryland puclic schools

# %% [markdown]
# Scrape https://www.marylandpublicschools.org/stateboard/Pages/Meetings-2018.aspx (Links to an external site.)
# <li>Tier 1: Scrape the date, URL to agenda, URL to board minutes</li>
# <li>Tier 2: Download agenda items to an "agendas" folder and board minutes to a "minutes" folder</li>

# %% [markdown]
# ## Tier 1: Scrape the date, URL to agenda, URL to board minutes

# %%
url = "https://www.marylandpublicschools.org/stateboard/Pages/Meetings-2018.aspx"

# %%
response = requests.get(url)
soup = bs(response.content)

# %%
meetings_list = []
parent_directory = "https://www.marylandpublicschools.org"

tags = soup.select("tbody > tr")

for tag in tags[2:]:
    #date
    try:
        date = tag.font.text
    except:
        date = tag.select_one("span").text
    
    #agenda
    ##url to agenda page
    agenda_page = tag.select_one("a[href$='.aspx']")['href']
    agenda_page = parent_directory + agenda_page if "http" not in agenda_page else agenda_page
    ##pdf file for agenda
    response = requests.get(agenda_page)
    soup = bs(response.content)
    agenda = soup.select_one("a[href$='.pdf'][title~=Agenda]")['href']
    agenda = parent_directory + agenda if "http" not in agenda else agenda
    
    #minutes
    minutes = tag.select_one("a[href$='.pdf']")['href']
    minutes = parent_directory + minutes if "http" not in minutes else minutes
    
    #data
    data = {
        "date": date,
        "agenda": agenda,
        "minutes": minutes
    }
    meetings_list.append(data)
    
    time.sleep(1)

# %%
meetings_df = pd.DataFrame(meetings_list)

# %%
meetings_df.date = meetings_df.date.str.replace('\n','')

# %%
meetings_df
# Out:
#                          date  \
# 0     January 29, 2018 Monday
# 1    January 30, 2018 Tuesday
# 2           February 27, 2018
# 3      March 20, 2018 Tuesday
# 4              April 24, 2018
# 5                May 22, 2018
# 6               June 20, 2018
# 7               July 24, 2018
# 8     August 28, 2018 Tuesday
# 9   September 25, 2018Tuesday
# 10           October 23, 2018
# 11   December 4, 2018 Tuesday
#
#                                                agenda  \
# 0   https://www.marylandpublicschools.org/stateboa...
# 1   https://www.marylandpublicschools.org/stateboa...
# 2   https://www.marylandpublicschools.org/stateboa...
# 3   https://www.marylandpublicschools.org/stateboa...
# 4   https://www.marylandpublicschools.org/stateboa...
# 5   https://www.marylandpublicschools.org/stateboa...
# 6   https://www.marylandpublicschools.org/stateboa...
# 7   https://www.marylandpublicschools.org/stateboa...
# 8   https://www.marylandpublicschools.org/stateboa...
# 9   https://www.marylandpublicschools.org/stateboa...
# 10  https://www.marylandpublicschools.org/stateboa...
# 11  https://www.marylandpublicschools.org/stateboa...
#
#                                               minutes
# 0   https://www.marylandpublicschools.org/stateboa...
# 1   https://www.marylandpublicschools.org/stateboa...
# 2   https://www.marylandpublicschools.org/stateboa...
# 3   https://www.marylandpublicschools.org/stateboa...
# 4   https://www.marylandpublicschools.org/stateboa...
# 5   https://www.marylandpublicschools.org/stateboa...
# 6   https://www.marylandpublicschools.org/stateboa...
# 7   https://www.marylandpublicschools.org/stateboa...
# 8   https://www.marylandpublicschools.org/stateboa...
# 9   https://www.marylandpublicschools.org/stateboa...
# 10  https://www.marylandpublicschools.org/stateboa...
# 11  https://www.marylandpublicschools.org/stateboa...

# %% [markdown]
# ## Tier 2: Download agenda items to an "agendas" folder and board minutes to a "minutes" folder

# %%
file_content = '\n'.join(meetings_df.agenda)

with open("urls.txt", "w") as f:
    f.write(file_content)

# %%
# !wget -i urls.txt --directory-prefix=agendas
# Out:
# --2022-07-12 16:47:35--  https://www.marylandpublicschools.org/stateboard/Documents/01292018/01292018BoardAgenda.pdf
# Resolving www.marylandpublicschools.org (www.marylandpublicschools.org)... 167.102.224.186
# Connecting to www.marylandpublicschools.org (www.marylandpublicschools.org)|167.102.224.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23062 (23K) [application/pdf]
# Saving to: ‘agendas/01292018BoardAgenda.pdf’
#
# 01292018BoardAgenda 100%[===================>]  22.52K  --.-KB/s    in 0.01s
#
# 2022-07-12 16:47:35 (1.71 MB/s) - ‘agendas/01292018BoardAgenda.pdf’ saved [23062/23062]
#
# --2022-07-12 16:47:35--  https://www.marylandpublicschools.org/stateboard/Documents/01302018/01302018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 39305 (38K) [application/pdf]
# Saving to: ‘agendas/01302018BoardAgenda.pdf’
#
# 01302018BoardAgenda 100%[===================>]  38.38K  6.38KB/s    in 63s
#
# 2022-07-12 16:48:38 (624 B/s) - ‘agendas/01302018BoardAgenda.pdf’ saved [39305/39305]
#
# --2022-07-12 16:48:38--  https://www.marylandpublicschools.org/stateboard/Documents/02272018/02272018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 35793 (35K) [application/pdf]
# Saving to: ‘agendas/02272018BoardAgenda.pdf’
#
# 02272018BoardAgenda 100%[===================>]  34.95K  --.-KB/s    in 0.04s
#
# 2022-07-12 16:48:38 (935 KB/s) - ‘agendas/02272018BoardAgenda.pdf’ saved [35793/35793]
#
# --2022-07-12 16:48:38--  https://www.marylandpublicschools.org/stateboard/Documents/03202018/03202018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 306285 (299K) [application/pdf]
# Saving to: ‘agendas/03202018BoardAgenda.pdf’
#
# 03202018BoardAgenda 100%[===================>] 299.11K   211KB/s    in 1.4s
#
# 2022-07-12 16:48:40 (211 KB/s) - ‘agendas/03202018BoardAgenda.pdf’ saved [306285/306285]
#
# --2022-07-12 16:48:40--  https://www.marylandpublicschools.org/stateboard/Documents/04242018/04242018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90507 (88K) [application/pdf]
# Saving to: ‘agendas/04242018BoardAgenda.pdf’
#
# 04242018BoardAgenda 100%[===================>]  88.39K  27.7KB/s    in 3.2s
#
# 2022-07-12 16:48:43 (27.7 KB/s) - ‘agendas/04242018BoardAgenda.pdf’ saved [90507/90507]
#
# --2022-07-12 16:48:43--  https://www.marylandpublicschools.org/stateboard/Documents/05222018/05222018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 107891 (105K) [application/pdf]
# Saving to: ‘agendas/05222018BoardAgenda.pdf’
#
# 05222018BoardAgenda 100%[===================>] 105.36K  --.-KB/s    in 0.09s
#
# 2022-07-12 16:48:43 (1.16 MB/s) - ‘agendas/05222018BoardAgenda.pdf’ saved [107891/107891]
#
# --2022-07-12 16:48:43--  https://www.marylandpublicschools.org/stateboard/Documents/06202018/06202018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 115188 (112K) [application/pdf]
# Saving to: ‘agendas/06202018BoardAgenda.pdf’
#
# 06202018BoardAgenda 100%[===================>] 112.49K  --.-KB/s    in 0.07s
#
# 2022-07-12 16:48:43 (1.66 MB/s) - ‘agendas/06202018BoardAgenda.pdf’ saved [115188/115188]
#
# --2022-07-12 16:48:43--  https://www.marylandpublicschools.org/stateboard/Documents/07242018/07242018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 113003 (110K) [application/pdf]
# Saving to: ‘agendas/07242018BoardAgenda.pdf’
#
# 07242018BoardAgenda 100%[===================>] 110.35K  --.-KB/s    in 0.05s
#
# 2022-07-12 16:48:43 (2.21 MB/s) - ‘agendas/07242018BoardAgenda.pdf’ saved [113003/113003]
#
# --2022-07-12 16:48:43--  https://www.marylandpublicschools.org/stateboard/Documents/08282018/08282018BoardAgenda.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 658871 (643K) [application/pdf]
# Saving to: ‘agendas/08282018BoardAgenda.pdf’
#
# 08282018BoardAgenda 100%[===================>] 643.43K  2.86MB/s    in 0.2s
#
# 2022-07-12 16:48:44 (2.86 MB/s) - ‘agendas/08282018BoardAgenda.pdf’ saved [658871/658871]
#
# --2022-07-12 16:48:44--  https://www.marylandpublicschools.org/stateboard/Documents/09252018/BoardAgenda09252018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 653411 (638K) [application/pdf]
# Saving to: ‘agendas/BoardAgenda09252018.pdf’
#
# BoardAgenda09252018 100%[===================>] 638.10K   299KB/s    in 7.4s
#
# 2022-07-12 16:48:51 (86.1 KB/s) - ‘agendas/BoardAgenda09252018.pdf’ saved [653411/653411]
#
# --2022-07-12 16:48:51--  https://www.marylandpublicschools.org/stateboard/Documents/10232018/BoardAgenda10232018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 658750 (643K) [application/pdf]
# Saving to: ‘agendas/BoardAgenda10232018.pdf’
#
# BoardAgenda10232018 100%[===================>] 643.31K   188KB/s    in 3.4s
#
# 2022-07-12 16:48:55 (188 KB/s) - ‘agendas/BoardAgenda10232018.pdf’ saved [658750/658750]
#
# --2022-07-12 16:48:55--  https://www.marylandpublicschools.org/stateboard/Documents/12042018/BoardAgenda12042018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 653222 (638K) [application/pdf]
# Saving to: ‘agendas/BoardAgenda12042018.pdf’
#
# BoardAgenda12042018 100%[===================>] 637.91K   440KB/s    in 1.4s
#
# 2022-07-12 16:48:56 (440 KB/s) - ‘agendas/BoardAgenda12042018.pdf’ saved [653222/653222]
#
# FINISHED --2022-07-12 16:48:56--
# Total wall clock time: 1m 21s
# Downloaded: 12 files, 3.3M in 1m 20s (42.0 KB/s)

# %%
file_content = '\n'.join(meetings_df.minutes)

with open("urls.txt", "w") as f:
    f.write(file_content)

# %%
# !wget -i urls.txt --directory-prefix=minutes
# Out:
# --2022-07-12 16:49:08--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/January292018.pdf
# Resolving www.marylandpublicschools.org (www.marylandpublicschools.org)... 167.102.224.186
# Connecting to www.marylandpublicschools.org (www.marylandpublicschools.org)|167.102.224.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75473 (74K) [application/pdf]
# Saving to: ‘minutes/January292018.pdf’
#
# January292018.pdf   100%[===================>]  73.70K  60.7KB/s    in 1.2s
#
# 2022-07-12 16:49:09 (60.7 KB/s) - ‘minutes/January292018.pdf’ saved [75473/75473]
#
# --2022-07-12 16:49:09--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/January302018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 793530 (775K) [application/pdf]
# Saving to: ‘minutes/January302018.pdf’
#
# January302018.pdf   100%[===================>] 774.93K   435KB/s    in 1.8s
#
# 2022-07-12 16:49:11 (435 KB/s) - ‘minutes/January302018.pdf’ saved [793530/793530]
#
# --2022-07-12 16:49:11--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/February272018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 383428 (374K) [application/pdf]
# Saving to: ‘minutes/February272018.pdf’
#
# February272018.pdf  100%[===================>] 374.44K   296KB/s    in 1.3s
#
# 2022-07-12 16:49:13 (296 KB/s) - ‘minutes/February272018.pdf’ saved [383428/383428]
#
# --2022-07-12 16:49:13--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/March202018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 375994 (367K) [application/pdf]
# Saving to: ‘minutes/March202018.pdf’
#
# March202018.pdf     100%[===================>] 367.18K  1.87MB/s    in 0.2s
#
# 2022-07-12 16:49:13 (1.87 MB/s) - ‘minutes/March202018.pdf’ saved [375994/375994]
#
# --2022-07-12 16:49:13--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/April242018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 370498 (362K) [application/pdf]
# Saving to: ‘minutes/April242018.pdf’
#
# April242018.pdf     100%[===================>] 361.81K  --.-KB/s    in 0.1s
#
# 2022-07-12 16:49:13 (2.88 MB/s) - ‘minutes/April242018.pdf’ saved [370498/370498]
#
# --2022-07-12 16:49:13--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/May222018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 351443 (343K) [application/pdf]
# Saving to: ‘minutes/May222018.pdf’
#
# May222018.pdf       100%[===================>] 343.21K   142KB/s    in 16s
#
# 2022-07-12 16:49:29 (21.5 KB/s) - ‘minutes/May222018.pdf’ saved [351443/351443]
#
# --2022-07-12 16:49:29--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/June202018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 336017 (328K) [application/pdf]
# Saving to: ‘minutes/June202018.pdf’
#
# June202018.pdf      100%[===================>] 328.14K  51.2KB/s    in 9.4s
#
# 2022-07-12 16:49:39 (34.9 KB/s) - ‘minutes/June202018.pdf’ saved [336017/336017]
#
# --2022-07-12 16:49:39--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/July242018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1047494 (1023K) [application/pdf]
# Saving to: ‘minutes/July242018.pdf’
#
# July242018.pdf      100%[===================>]   1023K  1.59MB/s    in 0.6s
#
# 2022-07-12 16:49:40 (1.59 MB/s) - ‘minutes/July242018.pdf’ saved [1047494/1047494]
#
# --2022-07-12 16:49:40--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/August282018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 395800 (387K) [application/pdf]
# Saving to: ‘minutes/August282018.pdf’
#
# August282018.pdf    100%[===================>] 386.52K   763KB/s    in 0.5s
#
# 2022-07-12 16:49:41 (763 KB/s) - ‘minutes/August282018.pdf’ saved [395800/395800]
#
# --2022-07-12 16:49:41--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/September252018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 998493 (975K) [application/pdf]
# Saving to: ‘minutes/September252018.pdf’
#
# September252018.pdf 100%[===================>] 975.09K   676KB/s    in 1.4s
#
# 2022-07-12 16:49:42 (676 KB/s) - ‘minutes/September252018.pdf’ saved [998493/998493]
#
# --2022-07-12 16:49:42--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/October232018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1013054 (989K) [application/pdf]
# Saving to: ‘minutes/October232018.pdf’
#
# October232018.pdf   100%[===================>] 989.31K   715KB/s    in 1.4s
#
# 2022-07-12 16:49:44 (715 KB/s) - ‘minutes/October232018.pdf’ saved [1013054/1013054]
#
# --2022-07-12 16:49:44--  https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/December042018.pdf
# Reusing existing connection to www.marylandpublicschools.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1078429 (1.0M) [application/pdf]
# Saving to: ‘minutes/December042018.pdf’
#
# December042018.pdf  100%[===================>]   1.03M   422KB/s    in 2.5s
#
# 2022-07-12 16:49:46 (422 KB/s) - ‘minutes/December042018.pdf’ saved [1078429/1078429]
#
# FINISHED --2022-07-12 16:49:46--
# Total wall clock time: 38s
# Downloaded: 12 files, 6.9M in 36s (194 KB/s)

# %% [markdown]
# # Mineral County School District
#
# Scrape http://www.nvmcsd.org/our-school-board/meetings/agendas (Links to an external site.)
# <li>Tier 1: Scrape the name of the link and the URL</li>
# <li>Tier 2: Add a column for the date (you'll need to manually edit some, probably [but using pandas!])</li>
# <li>Tier 3: Download the PDFs but name them after the date</li>

# %% [markdown]
# ## Tier 1: Scrape the name of the link and the URL

# %%
url = "http://www.nvmcsd.org/our-school-board/meetings/agendas"

# %%
response = requests.get(url, headers=headers)

# %%
soup = bs(response.content)

# %%
tags = soup.select(".kt-accordion-panel-inner")

# %%
names = []
urls = []

for tag in tags[:2]:
    elements = tag.select("a[href$='.pdf']")
    names = names + [element.text for element in elements]
    urls = urls + [element['href'] for element in elements]

# %%
df = pd.DataFrame({'name':names, "url": urls})

# %%
df.head()
# Out:
#                                         name  \
# 0         July 12, 2022 School Board Meeting
# 1  June 8, 2022 Special School Board Meeting
# 2  May 31, 2022 Special School Board Meeting
# 3                                    Item #2
# 4                                    Item #3
#
#                                                  url
# 0  https://nvmcsd.wpengine.com/wp-content/uploads...
# 1  https://nvmcsd.wpengine.com/wp-content/uploads...
# 2  https://nvmcsd.wpengine.com/wp-content/uploads...
# 3  https://nvmcsd.wpengine.com/wp-content/uploads...
# 4  https://nvmcsd.wpengine.com/wp-content/uploads...

# %% [markdown]
# ## Tier 2: Add a column for the date (you'll need to manually edit some, probably [but using pandas!])

# %%
#extract dates
df["date"] = df.name.str.extract("(.*\d\d\d\d)")

# %%
#manually edit some rows
df.loc[df.name=="8-10-21 Board Agenda","date"] = "August 10, 2021"
df.loc[df.name=="anuary 5, 2022 MCSD Safety Committee Meeting","date"] = "January 5, 2022"

# %%
#strftime + ffill
df.date = pd.to_datetime(df.date, errors="coerce").ffill()

# %%
df.head()
# Out:
#                                         name  \
# 0         July 12, 2022 School Board Meeting
# 1  June 8, 2022 Special School Board Meeting
# 2  May 31, 2022 Special School Board Meeting
# 3                                    Item #2
# 4                                    Item #3
#
#                                                  url       date
# 0  https://nvmcsd.wpengine.com/wp-content/uploads... 2022-07-12
# 1  https://nvmcsd.wpengine.com/wp-content/uploads... 2022-06-08
# 2  https://nvmcsd.wpengine.com/wp-content/uploads... 2022-05-31
# 3  https://nvmcsd.wpengine.com/wp-content/uploads... 2022-05-31
# 4  https://nvmcsd.wpengine.com/wp-content/uploads... 2022-05-31

# %% [markdown]
# ## Tier 3: Download the PDFs but name them after the date

# %%
file_content = '\n'.join(df.url)

with open("urls.txt", "w") as f:
    f.write(file_content)

# %%
#I couldn't figure out how I can download multiple files
#and change the file names
#in one line with wget

#wget -i urls.txt -O new_file_nameslist.txt --directory-prefix=mineral-county

# %%
#so I did 1) download, 2) rename separately
#step 1: I download files first
# !wget -i urls.txt --directory-prefix=mineral-county
# Out:
# --2022-07-12 16:48:57--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/07/7.12.22-backup.pdf
# Resolving nvmcsd.wpengine.com (nvmcsd.wpengine.com)... 35.227.4.241
# Connecting to nvmcsd.wpengine.com (nvmcsd.wpengine.com)|35.227.4.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3474406 (3.3M) [application/pdf]
# Saving to: ‘mineral-county/7.12.22-backup.pdf’
#
# 7.12.22-backup.pdf  100%[===================>]   3.31M  9.67MB/s    in 0.3s
#
# 2022-07-12 16:48:57 (9.67 MB/s) - ‘mineral-county/7.12.22-backup.pdf’ saved [3474406/3474406]
#
# --2022-07-12 16:48:57--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/06/6.8.22-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 44236 (43K) [application/pdf]
# Saving to: ‘mineral-county/6.8.22-agenda.pdf’
#
# 6.8.22-agenda.pdf   100%[===================>]  43.20K  --.-KB/s    in 0.02s
#
# 2022-07-12 16:48:57 (2.18 MB/s) - ‘mineral-county/6.8.22-agenda.pdf’ saved [44236/44236]
#
# --2022-07-12 16:48:57--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/board-backup5.31.22.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 209667 (205K) [application/pdf]
# Saving to: ‘mineral-county/board-backup5.31.22.pdf’
#
# board-backup5.31.22 100%[===================>] 204.75K  --.-KB/s    in 0.02s
#
# 2022-07-12 16:48:57 (9.57 MB/s) - ‘mineral-county/board-backup5.31.22.pdf’ saved [209667/209667]
#
# --2022-07-12 16:48:57--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/item2.5.31.22.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2131595 (2.0M) [application/pdf]
# Saving to: ‘mineral-county/item2.5.31.22.pdf’
#
# item2.5.31.22.pdf   100%[===================>]   2.03M  11.9MB/s    in 0.2s
#
# 2022-07-12 16:48:57 (11.9 MB/s) - ‘mineral-county/item2.5.31.22.pdf’ saved [2131595/2131595]
#
# --2022-07-12 16:48:57--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/item3.5.31.22.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1753944 (1.7M) [application/pdf]
# Saving to: ‘mineral-county/item3.5.31.22.pdf’
#
# item3.5.31.22.pdf   100%[===================>]   1.67M  --.-KB/s    in 0.1s
#
# 2022-07-12 16:48:58 (17.2 MB/s) - ‘mineral-county/item3.5.31.22.pdf’ saved [1753944/1753944]
#
# --2022-07-12 16:48:58--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/5.17.22-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 74602 (73K) [application/pdf]
# Saving to: ‘mineral-county/5.17.22-agenda.pdf’
#
# 5.17.22-agenda.pdf  100%[===================>]  72.85K  --.-KB/s    in 0.02s
#
# 2022-07-12 16:48:58 (3.33 MB/s) - ‘mineral-county/5.17.22-agenda.pdf’ saved [74602/74602]
#
# --2022-07-12 16:48:58--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/5.10.22-budget-meeting.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36695 (36K) [application/pdf]
# Saving to: ‘mineral-county/5.10.22-budget-meeting.pdf’
#
# 5.10.22-budget-meet 100%[===================>]  35.83K  --.-KB/s    in 0.02s
#
# 2022-07-12 16:48:58 (1.77 MB/s) - ‘mineral-county/5.10.22-budget-meeting.pdf’ saved [36695/36695]
#
# --2022-07-12 16:48:58--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/5.6.22-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 882264 (862K) [application/pdf]
# Saving to: ‘mineral-county/5.6.22-backup.pdf’
#
# 5.6.22-backup.pdf   100%[===================>] 861.59K  --.-KB/s    in 0.07s
#
# 2022-07-12 16:48:58 (11.4 MB/s) - ‘mineral-county/5.6.22-backup.pdf’ saved [882264/882264]
#
# --2022-07-12 16:48:58--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/05/board-backup-5.3.22.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 704846 (688K) [application/pdf]
# Saving to: ‘mineral-county/board-backup-5.3.22.pdf’
#
# board-backup-5.3.22 100%[===================>] 688.33K  --.-KB/s    in 0.07s
#
# 2022-07-12 16:48:58 (9.27 MB/s) - ‘mineral-county/board-backup-5.3.22.pdf’ saved [704846/704846]
#
# --2022-07-12 16:48:58--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/04/4.19.22-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6556753 (6.3M) [application/pdf]
# Saving to: ‘mineral-county/4.19.22-backup.pdf’
#
# 4.19.22-backup.pdf  100%[===================>]   6.25M  6.55MB/s    in 1.0s
#
# 2022-07-12 16:48:59 (6.55 MB/s) - ‘mineral-county/4.19.22-backup.pdf’ saved [6556753/6556753]
#
# --2022-07-12 16:48:59--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/04/4.19.22-backup-item-3.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1685080 (1.6M) [application/pdf]
# Saving to: ‘mineral-county/4.19.22-backup-item-3.pdf’
#
# 4.19.22-backup-item 100%[===================>]   1.61M  8.10MB/s    in 0.2s
#
# 2022-07-12 16:48:59 (8.10 MB/s) - ‘mineral-county/4.19.22-backup-item-3.pdf’ saved [1685080/1685080]
#
# --2022-07-12 16:48:59--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/04/4.5.22-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3264914 (3.1M) [application/pdf]
# Saving to: ‘mineral-county/4.5.22-backup.pdf’
#
# 4.5.22-backup.pdf   100%[===================>]   3.11M  9.12MB/s    in 0.3s
#
# 2022-07-12 16:48:59 (9.12 MB/s) - ‘mineral-county/4.5.22-backup.pdf’ saved [3264914/3264914]
#
# --2022-07-12 16:48:59--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/03/3.15.22-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1987738 (1.9M) [application/pdf]
# Saving to: ‘mineral-county/3.15.22-backup.pdf’
#
# 3.15.22-backup.pdf  100%[===================>]   1.90M  7.82MB/s    in 0.2s
#
# 2022-07-12 16:49:00 (7.82 MB/s) - ‘mineral-county/3.15.22-backup.pdf’ saved [1987738/1987738]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/02/3.1.22-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2486790 (2.4M) [application/pdf]
# Saving to: ‘mineral-county/3.1.22-backup.pdf’
#
# 3.1.22-backup.pdf   100%[===================>]   2.37M  9.93MB/s    in 0.2s
#
# 2022-07-12 16:49:00 (9.93 MB/s) - ‘mineral-county/3.1.22-backup.pdf’ saved [2486790/2486790]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/02/2.4.22-regular-meeting-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 438593 (428K) [application/pdf]
# Saving to: ‘mineral-county/2.4.22-regular-meeting-backup.pdf’
#
# 2.4.22-regular-meet 100%[===================>] 428.31K  --.-KB/s    in 0.06s
#
# 2022-07-12 16:49:00 (6.67 MB/s) - ‘mineral-county/2.4.22-regular-meeting-backup.pdf’ saved [438593/438593]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/02/2.4.22-capital-meeting-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 199439 (195K) [application/pdf]
# Saving to: ‘mineral-county/2.4.22-capital-meeting-backup.pdf’
#
# 2.4.22-capital-meet 100%[===================>] 194.76K  --.-KB/s    in 0.03s
#
# 2022-07-12 16:49:00 (7.49 MB/s) - ‘mineral-county/2.4.22-capital-meeting-backup.pdf’ saved [199439/199439]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/12/1.4.22-agenda-and-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965611 (943K) [application/pdf]
# Saving to: ‘mineral-county/1.4.22-agenda-and-backup.pdf’
#
# 1.4.22-agenda-and-b 100%[===================>] 942.98K  --.-KB/s    in 0.1s
#
# 2022-07-12 16:49:00 (9.59 MB/s) - ‘mineral-county/1.4.22-agenda-and-backup.pdf’ saved [965611/965611]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/12/safety-committee-1.5.22.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42168 (41K) [application/pdf]
# Saving to: ‘mineral-county/safety-committee-1.5.22.pdf’
#
# safety-committee-1. 100%[===================>]  41.18K  --.-KB/s    in 0.001s
#
# 2022-07-12 16:49:00 (29.0 MB/s) - ‘mineral-county/safety-committee-1.5.22.pdf’ saved [42168/42168]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/01/1.14.22-board-meeting.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36695 (36K) [application/pdf]
# Saving to: ‘mineral-county/1.14.22-board-meeting.pdf’
#
# 1.14.22-board-meeti 100%[===================>]  35.83K  --.-KB/s    in 0.001s
#
# 2022-07-12 16:49:00 (26.9 MB/s) - ‘mineral-county/1.14.22-board-meeting.pdf’ saved [36695/36695]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/01/1.14.22-amended-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 39416 (38K) [application/pdf]
# Saving to: ‘mineral-county/1.14.22-amended-agenda.pdf’
#
# 1.14.22-amended-age 100%[===================>]  38.49K  --.-KB/s    in 0.001s
#
# 2022-07-12 16:49:00 (37.8 MB/s) - ‘mineral-county/1.14.22-amended-agenda.pdf’ saved [39416/39416]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2022/01/1.21.22-policy.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 40436 (39K) [application/pdf]
# Saving to: ‘mineral-county/1.21.22-policy.pdf’
#
# 1.21.22-policy.pdf  100%[===================>]  39.49K  --.-KB/s    in 0.001s
#
# 2022-07-12 16:49:00 (35.2 MB/s) - ‘mineral-county/1.21.22-policy.pdf’ saved [40436/40436]
#
# --2022-07-12 16:49:00--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/backup-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2727926 (2.6M) [application/pdf]
# Saving to: ‘mineral-county/backup-agenda.pdf’
#
# backup-agenda.pdf   100%[===================>]   2.60M  6.92MB/s    in 0.4s
#
# 2022-07-12 16:49:01 (6.92 MB/s) - ‘mineral-county/backup-agenda.pdf’ saved [2727926/2727926]
#
# --2022-07-12 16:49:01--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/item-5.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1148683 (1.1M) [application/pdf]
# Saving to: ‘mineral-county/item-5.pdf’
#
# item-5.pdf          100%[===================>]   1.09M  --.-KB/s    in 0.1s
#
# 2022-07-12 16:49:01 (9.62 MB/s) - ‘mineral-county/item-5.pdf’ saved [1148683/1148683]
#
# --2022-07-12 16:49:01--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/item-6.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1814193 (1.7M) [application/pdf]
# Saving to: ‘mineral-county/item-6.pdf’
#
# item-6.pdf          100%[===================>]   1.73M  8.31MB/s    in 0.2s
#
# 2022-07-12 16:49:01 (8.31 MB/s) - ‘mineral-county/item-6.pdf’ saved [1814193/1814193]
#
# --2022-07-12 16:49:01--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/item-7.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 378250 (369K) [application/pdf]
# Saving to: ‘mineral-county/item-7.pdf’
#
# item-7.pdf          100%[===================>] 369.38K  --.-KB/s    in 0.06s
#
# 2022-07-12 16:49:01 (5.75 MB/s) - ‘mineral-county/item-7.pdf’ saved [378250/378250]
#
# --2022-07-12 16:49:01--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/item-8.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1478613 (1.4M) [application/pdf]
# Saving to: ‘mineral-county/item-8.pdf’
#
# item-8.pdf          100%[===================>]   1.41M  --.-KB/s    in 0.1s
#
# 2022-07-12 16:49:01 (9.82 MB/s) - ‘mineral-county/item-8.pdf’ saved [1478613/1478613]
#
# --2022-07-12 16:49:01--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/item-9.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 442687 (432K) [application/pdf]
# Saving to: ‘mineral-county/item-9.pdf’
#
# item-9.pdf          100%[===================>] 432.31K  --.-KB/s    in 0.09s
#
# 2022-07-12 16:49:01 (4.93 MB/s) - ‘mineral-county/item-9.pdf’ saved [442687/442687]
#
# --2022-07-12 16:49:01--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/08/item-10.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3360862 (3.2M) [application/pdf]
# Saving to: ‘mineral-county/item-10.pdf’
#
# item-10.pdf         100%[===================>]   3.21M  7.33MB/s    in 0.4s
#
# 2022-07-12 16:49:02 (7.33 MB/s) - ‘mineral-county/item-10.pdf’ saved [3360862/3360862]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/09/9.7.21-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 87985 (86K) [application/pdf]
# Saving to: ‘mineral-county/9.7.21-agenda.pdf’
#
# 9.7.21-agenda.pdf   100%[===================>]  85.92K  --.-KB/s    in 0.007s
#
# 2022-07-12 16:49:02 (12.6 MB/s) - ‘mineral-county/9.7.21-agenda.pdf’ saved [87985/87985]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/09/9.21.21-agenda-website.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 584814 (571K) [application/pdf]
# Saving to: ‘mineral-county/9.21.21-agenda-website.pdf’
#
# 9.21.21-agenda-webs 100%[===================>] 571.11K  --.-KB/s    in 0.06s
#
# 2022-07-12 16:49:02 (8.80 MB/s) - ‘mineral-county/9.21.21-agenda-website.pdf’ saved [584814/584814]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/09/board-backup-9.21.21.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1248942 (1.2M) [application/pdf]
# Saving to: ‘mineral-county/board-backup-9.21.21.pdf’
#
# board-backup-9.21.2 100%[===================>]   1.19M  --.-KB/s    in 0.1s
#
# 2022-07-12 16:49:02 (9.33 MB/s) - ‘mineral-county/board-backup-9.21.21.pdf’ saved [1248942/1248942]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/09/9.21.21-insurance-website.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 310016 (303K) [application/pdf]
# Saving to: ‘mineral-county/9.21.21-insurance-website.pdf’
#
# 9.21.21-insurance-w 100%[===================>] 302.75K  --.-KB/s    in 0.04s
#
# 2022-07-12 16:49:02 (7.54 MB/s) - ‘mineral-county/9.21.21-insurance-website.pdf’ saved [310016/310016]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/09/10.5.21-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57122 (56K) [application/pdf]
# Saving to: ‘mineral-county/10.5.21-agenda.pdf’
#
# 10.5.21-agenda.pdf  100%[===================>]  55.78K  --.-KB/s    in 0.004s
#
# 2022-07-12 16:49:02 (13.4 MB/s) - ‘mineral-county/10.5.21-agenda.pdf’ saved [57122/57122]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/10.5.21-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 477571 (466K) [application/pdf]
# Saving to: ‘mineral-county/10.5.21-backup.pdf’
#
# 10.5.21-backup.pdf  100%[===================>] 466.38K  --.-KB/s    in 0.05s
#
# 2022-07-12 16:49:02 (9.06 MB/s) - ‘mineral-county/10.5.21-backup.pdf’ saved [477571/477571]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/10.15.21-policy-committee.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36773 (36K) [application/pdf]
# Saving to: ‘mineral-county/10.15.21-policy-committee.pdf’
#
# 10.15.21-policy-com 100%[===================>]  35.91K  --.-KB/s    in 0s
#
# 2022-07-12 16:49:02 (272 MB/s) - ‘mineral-county/10.15.21-policy-committee.pdf’ saved [36773/36773]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/10.16.21-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55119 (54K) [application/pdf]
# Saving to: ‘mineral-county/10.16.21-agenda.pdf’
#
# 10.16.21-agenda.pdf 100%[===================>]  53.83K  --.-KB/s    in 0.006s
#
# 2022-07-12 16:49:02 (9.27 MB/s) - ‘mineral-county/10.16.21-agenda.pdf’ saved [55119/55119]
#
# --2022-07-12 16:49:02--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/10.16.21-backup.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3757648 (3.6M) [application/pdf]
# Saving to: ‘mineral-county/10.16.21-backup.pdf’
#
# 10.16.21-backup.pdf 100%[===================>]   3.58M  6.27MB/s    in 0.6s
#
# 2022-07-12 16:49:03 (6.27 MB/s) - ‘mineral-county/10.16.21-backup.pdf’ saved [3757648/3757648]
#
# --2022-07-12 16:49:03--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/10.19.21-insurance-meeting.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 33220 (32K) [application/pdf]
# Saving to: ‘mineral-county/10.19.21-insurance-meeting.pdf’
#
# 10.19.21-insurance- 100%[===================>]  32.44K  --.-KB/s    in 0.02s
#
# 2022-07-12 16:49:03 (1.52 MB/s) - ‘mineral-county/10.19.21-insurance-meeting.pdf’ saved [33220/33220]
#
# --2022-07-12 16:49:03--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/10.19.21-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68650 (67K) [application/pdf]
# Saving to: ‘mineral-county/10.19.21-agenda.pdf’
#
# 10.19.21-agenda.pdf 100%[===================>]  67.04K   133KB/s    in 0.5s
#
# 2022-07-12 16:49:04 (133 KB/s) - ‘mineral-county/10.19.21-agenda.pdf’ saved [68650/68650]
#
# --2022-07-12 16:49:04--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/11.2.21-insurance-agenda.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 300318 (293K) [application/pdf]
# Saving to: ‘mineral-county/11.2.21-insurance-agenda.pdf’
#
# 11.2.21-insurance-a 100%[===================>] 293.28K  --.-KB/s    in 0.06s
#
# 2022-07-12 16:49:04 (4.46 MB/s) - ‘mineral-county/11.2.21-insurance-agenda.pdf’ saved [300318/300318]
#
# --2022-07-12 16:49:04--  https://nvmcsd.wpengine.com/wp-content/uploads/2021/10/11.2.21-agenda-1.pdf
# Reusing existing connection to nvmcsd.wpengine.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 650590 (635K) [application/pdf]
# Saving to: ‘mineral-county/11.2.21-agenda-1.pdf’
#
# 11.2.21-agenda-1.pd 100%[===================>] 635.34K  --.-KB/s    in 0.08s
#
# 2022-07-12 16:49:04 (7.61 MB/s) - ‘mineral-county/11.2.21-agenda-1.pdf’ saved [650590/650590]
#
# FINISHED --2022-07-12 16:49:04--
# Total wall clock time: 7.1s
# Downloaded: 41 files, 44M in 6.0s (7.36 MB/s)

# %%
#step 2: rename filename
file_dir = "./mineral-county/"

for i in range(len(df)):
    sourcefile = file_dir + os.path.basename(df.url[i])
    date_count = ("-"+str((df.date[:i+1] == df.date[i]).sum())).replace("-1","")
    filename = file_dir + df.date[i].strftime('%Y-%m-%d') + date_count + ".pdf"
    os.rename(sourcefile, filename)

# %% [markdown]
# # RockTumbler
# Scrape https://rocktumbler.com/blog/rock-and-mineral-clubs/ (Links to an external site.)
# <li>Tier 1: Scrape all of the name and city</li>
# <li>Tier 2: Scrape the name, city, and URL</li>
# <li>Tier 3: Scrape the name, city, URL, and state name (you'll probably need to learn about "parent" nodes)</li>

# %% [markdown]
# ## Tier 1: Scrape all of the name and city

# %% [markdown]
# ## Tier 2: Scrape the name, city, and URL

# %%
url = "https://rocktumbler.com/blog/rock-and-mineral-clubs/"

# %%
response = requests.get(url)
doc = bs(response.content)

# %%
tags = doc.select("section>table>tr>td>a")

# %%
clubs = []
for tag in tags:
    try:
        data = {"name": tag.text,
                "city": tag.parent.next_sibling.next_sibling.text,
                "url" : tag['href']}
        clubs.append(data)
    except:
        print(tag.prettify())
        pass
# Out:
# <a href="https://rocktumbler.com/about-us.shtml#who">
#  Hobart M. King
# </a>

# %%
df = pd.DataFrame(clubs)

# %%
df.head()
# Out:
#                                  name        city  \
# 0  Alabama Mineral & Lapidary Society  Birmingham
# 1           Dothan Gem & Mineral Club      Dothan
# 2  Huntsville Gem and Mineral Society  Huntsville
# 3           Mobile Rock & Gem Society      Mobile
# 4    Montgomery Gem & Mineral Society  Montgomery
#
#                                                url
# 0                     http://www.lapidaryclub.com/
# 1              http://www.wiregrassrockhounds.com/
# 2                        http://huntsvillegms.org/
# 3                 http://www.mobilerockandgem.com/
# 4  http://montgomerygemandmineralsociety.com/mgms/

# %%
df.tail()
# Out:
#                                       name        city  \
# 484             Weis'n'Miners Geology Club     Menasha
# 485           Wisconsin Geological Society  West Allis
# 486                   Cody 59ers Rock Club        Cody
# 487       Riverton Mineral and Gem Society    Riverton
# 488  Wyoming State Mineral and Gem Society        Cody
#
#                                              url
# 484  http://www.weismuseum.org/geology-club.html
# 485         http://www.wisgeologicalsociety.com/
# 486                    http://www.cody59ers.com/
# 487                  http://www.rivertonmgs.com/
# 488            http://wymineralandgemsociety.org

# %% [markdown]
# ## Tier 3: Scrape the name, city, URL, and state name (you'll probably need to learn about "parent" nodes)

# %%
clubs = []
for tag in tags[:-1]:
    data = {"name": tag.text,
            "city": tag.parent.next_sibling.next_sibling.text,
            "url" : tag['href'],
            "state" : tag.parent.parent.parent.parent.h3.text}
    clubs.append(data)

# %%
df = pd.DataFrame(clubs)

# %%
df.state = df.state.str.extract("(.*) Rock and Mineral Clubs")

# %%
df
# Out:
#                                       name        city  \
# 0       Alabama Mineral & Lapidary Society  Birmingham
# 1                Dothan Gem & Mineral Club      Dothan
# 2       Huntsville Gem and Mineral Society  Huntsville
# 3                Mobile Rock & Gem Society      Mobile
# 4         Montgomery Gem & Mineral Society  Montgomery
# ..                                     ...         ...
# 484             Weis'n'Miners Geology Club     Menasha
# 485           Wisconsin Geological Society  West Allis
# 486                   Cody 59ers Rock Club        Cody
# 487       Riverton Mineral and Gem Society    Riverton
# 488  Wyoming State Mineral and Gem Society        Cody
#
#                                                  url      state
# 0                       http://www.lapidaryclub.com/    Alabama
# 1                http://www.wiregrassrockhounds.com/    Alabama
# 2                          http://huntsvillegms.org/    Alabama
# 3                   http://www.mobilerockandgem.com/    Alabama
# 4    http://montgomerygemandmineralsociety.com/mgms/    Alabama
# ..                                               ...        ...
# 484      http://www.weismuseum.org/geology-club.html  Wisconsin
# 485             http://www.wisgeologicalsociety.com/  Wisconsin
# 486                        http://www.cody59ers.com/    Wyoming
# 487                      http://www.rivertonmgs.com/    Wyoming
# 488                http://wymineralandgemsociety.org    Wyoming
#
# [489 rows x 4 columns]
