# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
import pandas as pd
import time

from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# /var/folders/m5/5y2tv80j62v6m1f84pdbl2vm0000gn/T/ipykernel_80967/1503906442.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
driver.get("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")

# %%
#choose License Program Type
dropdown = driver.find_element(By.ID, "pht_status")
Select(dropdown).select_by_value("COS")

#Input the last name
driver.find_element(By.ID, "pht_lnm").send_keys("Nguyen")

#submit
driver.find_element(By.XPATH, "/html/body/div/div/div[2]/div[1]/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]").click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this. **I step you through things bit by bit, so it's going to be a little different than we did in class.** Also, no `pd.read_html` allowed because this isn't actual tabular data!
#
# > You can use either Selenium by itself or Selenium+BeautifulSoup to scrape the results page. The choice is up to you!

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, maybe not, i's a heck of a lot of rows. Use `[:10]` to only do the first ten! For example, if you saved the table rows into `results` you might do something like this:
#
# ```python
# for result in results[:10]:
#     print(result)
# ```
#
# Although you'd want to print out the text from the row (I give example output below).
#
# > *Tip: If you're using Selenium, `By.TAG_NAME` is used if you don't have a class or ID. If you're using BeautifulSoup, just do your normal thing.*

# %% [markdown]
# The result should look something like this:
#
# ```
# Name and Location Order Basis for Order
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20210004784 Date: 11/16/2021
#
# Respondent is assessed an administrative penalty in the amount of $1,875. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, LONG D
# City: SAN SABA
# County: SAN SABA
# Zip Code: 76877
# ```

# %%
results = driver.find_elements(By.CSS_SELECTOR, "tr")

# %%
for result in results[1:11]:
    print(result.text)
    print('------')
# Out:
# NGUYEN, MAI T
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78717
#
#
# License #: 750076
#
# Complaint # COS20220000853 Date: 7/7/2022
#
# Respondent is assessed an administrative penalty in the amount of $7,500. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 3 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.
# ------
# NGUYEN, HUNG VU
# City: HOUSTON
# County: HARRIS
# Zip Code: 77086
#
#
# License #: 763912
#
# Complaint # COS20200013887 Date: 7/6/2022
#
# Respondent is assessed an administrative penalty in the amount of $3,000. Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to clean and disinfect multiple use implements after each customer; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# ------
# NGUYEN, MINH HIEN LUONG
# City: CARROLLTON
# County: DALLAS
# Zip Code: 75007
#
#
# License #: 777932
#
# Complaint # COS20210010437 Date: 6/27/2022
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ------
# NGUYEN, PHUONG T
# City: PLANO
# County: COLLIN
# Zip Code: 75023
#
#
# License #: 766293
#
# Complaint # COS20210014779 Date: 6/16/2022
#
# Respondent is assessed an administrative penalty in the amount of $6,800. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 9 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to utilize clean and disinfected implements; Respondent failed to clean and disinfect manicure tables prior to use for each client; Respondent failed to discard buffer blocks and porous nail files when exposed to a client's broken skin and/or unhealthy nails.
# ------
# NGUYEN, STEVEN MANH
# City: FORT WORTH
# County: TARRANT
# Zip Code: 76244
#
#
# License #: 773318
#
# Complaint # COS20200015190 Date: 6/9/2022
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# ------
# NGUYEN, LANG THU
# City: ALLEN
# County: COLLIN
# Zip Code: 75002
#
#
# License #: 744463
#
# Complaint # COS20200008154 Date: 6/2/2022
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# ------
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20200007790 Date: 5/2/2022
#
# Respondent is assessed an administrative penalty in the amount of $2,625. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging 11 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ------
# NGUYEN, NAM QUANG
# City: HARKER HEIGHTS
# County: BELL
# Zip Code: 76548
#
#
# License #: 745552
#
# Complaint # COS20210010525 Date: 4/27/2022
#
# Respondent is assessed an administrative penalty in the amount of $2,000. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 5 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ------
# NGUYEN, JAY TRI
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78266
#
#
# License #: 735165
#
# Complaint # COS20210015763 Date: 4/27/2022
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# ------
# NGUYEN, HUYEN THANH THI
# City: MURPHY
# County: COLLIN
# Zip Code: 75094
#
#
# License #: 789370
#
# Complaint # COS20210011311 Date: 4/26/2022
#
# Respondent is assessed an administrative penalty in the amount of $2,275. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent engaged in gross malpractice; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ------

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything when there's an error, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**
#
# Output should look like this:
#
# ```
# Doesn't have a name
# NGUYEN, THANH
# NGUYEN, LONG D
# NGUYEN, LUCIE HUONG
# NGUYEN, CHINH
# NGUYEN, JIMMY
# ```
#
# * *Tip: The name has a class you can use. The class name is reused in a lot of places, but because it's the first one you don't have to worry about that!*
# * *Tip: Instead of searching across the entire page – `driver.find_element` or `doc.select_one` – you should be doing your searching just inside of each **row** (I used this technique in the beginning of class with BeautifulSoup when we were scraping the books page)*

# %%
for result in results:
    try:
        name = result.find_elements(By.CSS_SELECTOR, ".results_text")[0].text
        print(name)
    except:
        print("It didn't work")
# Out:
# It didn't work
# NGUYEN, MAI T
# NGUYEN, HUNG VU
# NGUYEN, MINH HIEN LUONG
# NGUYEN, PHUONG T
# NGUYEN, STEVEN MANH
# NGUYEN, LANG THU
# NGUYEN, THANH
# NGUYEN, NAM QUANG
# NGUYEN, JAY TRI
# NGUYEN, HUYEN THANH THI
# NGUYEN, MATTHEW VIET
# NGUYEN, LIEU D
# NGUYEN, OANH
# NGUYEN, KIMLIEN
# NGUYEN, JOHNNY DAT
# NGUYEN, NHO THANH
# NGUYEN, KEN
# NGUYEN, MEJ X
# NGUYEN, THI THU HUNG
# NGUYEN, LOAN HONG ANH
# NGUYEN, HONG VU
# NGUYEN, LEHUONG
# NGUYEN, HAI THANH
# NGUYEN, CHI
# NGUYEN, THY DINH MINH
# NGUYEN, KATY
# NGUYEN, HIEU V
# NGUYEN, ANNA
# NGUYEN, NGA T
# NGUYEN, THANH
# NGUYEN, DAI T
# NGUYEN, LONG D
# NGUYEN, LUCIE HUONG
# NGUYEN, CHINH
# NGUYEN, HUNG VU
# NGUYEN, JIMMY
# NGUYEN, NAM
# NGUYEN, DUC
# NGUYEN, THU THAO THI
# NGUYEN, MINH NHU
# NGUYEN, DUNG VAN
# NGUYEN, TINH
# NGUYEN, HANG NU THANH
# NGUYEN, LAN N
# NGUYEN, TIEP HUY
# NGUYEN, DUNG
# NGUYEN, THAI VAN
# NGUYEN, THI THAO UYEN
# NGUYEN, THANH TRONG
# NGUYEN, KHANH V
# NGUYEN, DUC VAN
# NGUYEN, THI HOAN CHAU
# NGUYEN, PHUCHUNG
# NGUYEN, KIM
# NGUYEN, HUE VAN
# NGUYEN, HOAI THU T
# NGUYEN, NGHIA T
# NGUYEN, HANH THI
# NGUYEN, HUYEN
# NGUYEN, CHRISTINA M
# NGUYEN, THI THIBICH
# NGUYEN, KIM AN THI
# NGUYEN, VIVIAN KIM
# NGUYEN, LONG
# NGUYEN, MAI
# NGUYEN, CHINH THI
# NGUYEN, THU HA
# NGUYEN, HA THI THU
# NGUYEN, CHAU
# NGUYEN, HUNG VU
# NGUYEN, MIMI PHAM
# NGUYEN, HA
# NGUYEN, THAO HONG
# NGUYEN, CINDY
# NGUYEN, CHAU KHANH LINH
# NGUYEN, TRANG T
# NGUYEN, DUNG MINH
# NGUYEN, YEN NHI THI
# NGUYEN, JOHNNY DAT
# NGUYEN, KELLY PHUONG N
# NGUYEN, NGA THU
# NGUYEN, IVY
# NGUYEN, DIEMTRINH T
# NGUYEN, HUAN CAO
# NGUYEN, THOA KIM
# NGUYEN, TONY
# NGUYEN, HIEN
# NGUYEN, NGOC TRAM
# NGUYEN, TRAN NAM
# NGUYEN, PHILLIP
# NGUYEN, THUY T
# NGUYEN, TRACY
# NGUYEN, LE PHUC
# NGUYEN, HAI MINH
# NGUYEN, TUYET
# NGUYEN, BA VAN
# NGUYEN, LAN THANH
# NGUYEN, PHUOC BA
# NGUYEN, LINH THUY KIEU
# NGUYEN, TONY MINH
# NGUYEN, THANH
# NGUYEN, HIEN THI MINH
# NGUYEN, VAN NGOC THAO
# NGUYEN, TAM THANH
# NGUYEN, ANDY HUU
# NGUYEN, CUONG HULL
# NGUYEN, NANCY HOA
# NGUYEN, THOA THI KIM
# NGUYEN, TRANG
# NGUYEN, THONG VAN
# NGUYEN, TUAN
# NGUYEN, LYNDA
# NGUYEN, CATHY H
# NGUYEN, PAMELA DAN
# NGUYEN, SON QUOC
# NGUYEN, KIM
# NGUYEN, THAI VAN
# NGUYEN, HANH THI
# NGUYEN, DIEP THI NGOC
# NGUYEN, CASEY
# NGUYEN, ANTHONY VAN
# NGUYEN, CHRISTINA D
# NGUYEN, PHUONG T
# NGUYEN, KENNY
# NGUYEN, THAO (MINH THAO
# NGUYEN, KENNY
# NGUYEN, BA VAN
# NGUYEN, KHUYEN THI
# NGUYEN, SON DANG
# NGUYEN, TUYEN THANH
# NGUYEN, STEVEN THAI
# NGUYEN, CY VAN
# NGUYEN, KIM NGAN THI

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# Your results should look something like:
#
# ```
# Doesn't have a violation
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ...
# ```
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: If you're using Selenium by itself, you can get the HTML of something by doing `.get_attribute('innerHTML')` – that way it'll look like BeautifulSoup when you print it. It might help you diagnose your issue!*
# > - *Tip: Or I guess you could just skip the one with the problem...*

# %%
for result in results:
    try:
        basis = result.find_elements(By.CSS_SELECTOR, "td")[-1].text
        print(basis)
    except:
        print("It didn't work")
# Out:
# It didn't work
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 3 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.
# Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to clean and disinfect multiple use implements after each customer; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 9 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to utilize clean and disinfected implements; Respondent failed to clean and disinfect manicure tables prior to use for each client; Respondent failed to discard buffer blocks and porous nail files when exposed to a client's broken skin and/or unhealthy nails.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging 11 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 5 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent engaged in gross malpractice; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent used salon as a living, dining, or sleeping quarters; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent performed an act or practice for which the specialty salon is not licensed.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent used a prohibited implement to exfoliate and penetrate the dermis layer of the skin.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instruction; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent engaged in gross malpractice; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to post the human trafficking sign; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to remove soiled towels after use on each client.
# Respondent provided other cosmetology services while only holding a manicurist license; Respondent engaged in gross malpractice.
# Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 8 violations; Respondent failed to clean and disinfect all wax pots.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 4 violations; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent's employee failed to have a photograph attached to their license.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondents failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to maintain powdered alum, styptic powder, or a cyanoacrylate.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent performed or attempted to perform a practice of cosmetology with an expired license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to maintain powdered alum, styptic powder, or a cyanoacrylate.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondents leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging two violations; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent allowed a licensee to perform a cosmetology service on a client with a contagious condition.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Applicant has been convicted of a crime that was committed within 5 years of their application; Applicant has a deferred adjudication disposition which makes them unfit to hold a license.
# Respondent failed to clean their hands with soap and water or use a hand sanitizer prior to performing any cosmetology services to ensure a client health and safety.
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging three (3) violations; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent stored chemicals in a restroom accessible to the public.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging two (2) violations; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used. The Department is charging two (2) violations.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging two (2) violations; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to dispose of single use items after each use.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, Department is charging two (2) violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging two (2) violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging three (3) violations.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent was in possession of bottles containing methyl methacrylate monomer.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly. This constitutes two (2) violations.
# Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to have chairs made of or covered in a non-porous material so that they can be disinfected.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to discard single use implements after each use; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.
# Respondent failed properly clean and sanitize the metal implements used at the Salon.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean and disinfect all wax pots.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent operated a cosmetology salon without the appropriate license.
# Respondent interfered with a Department inspection of the salon.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# Output should look like this:
#
# ```
# Doesn't have a complaint number
# COS20210004784
# COS20210009745
# COS20210011484
# ...
# ```
#
# - *Tip: Think about the order of the elements. Can you count from the opposite direction than you normally do?*

# %%
for result in results:
    try:
        complaint_number = result.find_elements(By.CSS_SELECTOR, ".results_text")[-2].text
        print(complaint_number)
    except:
        print("Doesn't have a complaint number")
# Out:
# Doesn't have a complaint number
# COS20220000853
# COS20200013887
# COS20210010437
# COS20210014779
# COS20200015190
# COS20200008154
# COS20200007790
# COS20210010525
# COS20210015763
# COS20210011311
# COS20210003963
# COS20190017129
# COS20200010645
# COS20210012116
# COS20210011168
# COS20210014198
# COS20220008308
# COS20210010069
# COS20210011374
# COS20220001466
# COS20210015652
# COS20210015023
# COS20220001836
# COS20210010769
# COS20200012226
# COS20200006932
# COS20210010477
# COS20210005808
# COS20210008358
# COS20210004784
# COS20210005027
# COS20210009745
# COS20210011484
# COS20210011721
# COS20200006792
# COS20200007069
# COS20210010530
# COS20200007141
# COS20200000839
# COS20210009714
# COS20210005838
# COS20200010129
# COS20210003441
# COS20200009912
# COS20210004018
# COS20210000935
# COS20210003238
# COS20200005799
# COS20210004209
# COS20200012887
# COS20190014959
# COS20190011954
# COS20200016795
# COS20200016258
# COS20200017028
# COS20200016091
# COS20210001519
# COS20200012575
# COS20200007138
# COS20200010817
# COS20190012445
# COS20190010554
# COS20200009961
# COS20200011967
# COS20200007264
# COS20200009985
# COS20200014601
# COS20200015200
# COS20210002574
# COS20190011025
# COS20190010072
# COS20190016762
# COS20200010387
# COS20200010502
# COS20190008104
# COS20200010511
# COS20200004202
# COS20190004199
# COS20200000101
# COS20200011664
# COS20200010961
# COS20200008858
# COS20200008859
# COS20200009732
# COS20200006548
# COS20200009605
# COS20190016479
# COS20190012148
# COS20190010318
# COS20190014688
# COS20190004016
# COS20190016499
# COS20200006146
# COS20190016549
# COS20190017217
# COS20190016854
# COS20190017175
# COS20190013017
# COS20190016161
# COS20200000652
# COS20190007906
# COS20190003737
# COS20190006118
# COS20200002642
# COS20190009211
# COS20190010611
# COS20190010665
# COS20190001932
# COS20190014576
# COS20190001897
# COS20190009239
# COS20190009484
# COS20190010323
# COS20190011923
# COS20190005539
# COS20190010176
# COS20190010397
# COS20190011044
# COS20190003373
# COS20190010299
# COS20190013988
# COS20190012652
# COS20180015395
# COS20190010057
# COS20190010254
# COS20190000183
# COS20190010606
# COS20190010961
# COS20190010635
# COS20190014566
# COS20190010869
# COS20190007921
# COS2009004238D

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# Based on what you print out, the output might look something like:
#
# ```
# This row is broken: Name and Location Order Basis for Order
# {'name': 'NGUYEN, THANH', 'city': 'FRISCO', 'county': 'COLLIN', 'zip_code': '75034', 'complaint_no': 'COS20210004784', 'license_numbers': '790672', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.'}
# {'name': 'NGUYEN, LONG D', 'city': 'SAN SABA', 'county': 'SAN SABA', 'zip_code': '76877', 'complaint_no': 'COS20210009745', 'license_numbers': '760420, 1620583', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# ```
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
records = []
items = ["name", "city", "county", "zip_code", 'complaint_no', 'license_numbers','complaint']

for result in results:
    try:
        #"name", "city", "county", "zip_code", 'complaint_no', 'license_numbers'
        columns = result.find_elements(By.CSS_SELECTOR, "td")
        elements = columns[0].find_elements(By.CSS_SELECTOR, ".results_text")
        texts = [element.text for element in elements]

        #'complaint'
        texts.append(columns[-1].text)

        #make a dictionary
        record = dict(zip(items, texts))
        records.append(record)
    except:
        pass
    time.sleep(1)

# %%
records
# Out:
# [{'name': 'NGUYEN, MAI T',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip_code': '78717',
#   'complaint_no': '750076',
#   'license_numbers': 'COS20220000853',
#   'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 3 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone."},
#  {'name': 'NGUYEN, HUNG VU',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77086',
#   'complaint_no': '763912',
#   'license_numbers': 'COS20200013887',
#   'complaint': 'Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to clean and disinfect multiple use implements after each customer; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.'},
#  {'name': 'NGUYEN, MINH HIEN LUONG',
#   'city': 'CARROLLTON',
#   'county': 'DALLAS',
#   'zip_code': '75007',
#   'complaint_no': '777932',
#   'license_numbers': 'COS20210010437',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, PHUONG T',
#   'city': 'PLANO',
#   'county': 'COLLIN',
#   'zip_code': '75023',
#   'complaint_no': '766293',
#   'license_numbers': 'COS20210014779',
#   'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 9 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to utilize clean and disinfected implements; Respondent failed to clean and disinfect manicure tables prior to use for each client; Respondent failed to discard buffer blocks and porous nail files when exposed to a client's broken skin and/or unhealthy nails."},
#  {'name': 'NGUYEN, STEVEN MANH',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76244',
#   'complaint_no': '773318',
#   'license_numbers': 'COS20200015190',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'},
#  {'name': 'NGUYEN, LANG THU',
#   'city': 'ALLEN',
#   'county': 'COLLIN',
#   'zip_code': '75002',
#   'complaint_no': '744463',
#   'license_numbers': 'COS20200008154',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.'},
#  {'name': 'NGUYEN, THANH',
#   'city': 'FRISCO',
#   'county': 'COLLIN',
#   'zip_code': '75034',
#   'complaint_no': '790672',
#   'license_numbers': 'COS20200007790',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging 11 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, NAM QUANG',
#   'city': 'HARKER HEIGHTS',
#   'county': 'BELL',
#   'zip_code': '76548',
#   'complaint_no': '745552',
#   'license_numbers': 'COS20210010525',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 5 violations; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, JAY TRI',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78266',
#   'complaint_no': '735165',
#   'license_numbers': 'COS20210015763',
#   'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, HUYEN THANH THI',
#   'city': 'MURPHY',
#   'county': 'COLLIN',
#   'zip_code': '75094',
#   'complaint_no': '789370',
#   'license_numbers': 'COS20210011311',
#   'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent engaged in gross malpractice; Respondent failed to clean and disinfect manicure tables prior to use for each client."},
#  {'name': 'NGUYEN, MATTHEW VIET',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76119',
#   'complaint_no': '788863',
#   'license_numbers': 'COS20210003963',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent used salon as a living, dining, or sleeping quarters; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, LIEU D',
#   'city': 'HUMBLE',
#   'county': '',
#   'zip_code': '77346',
#   'complaint_no': '751344',
#   'license_numbers': 'COS20190017129',
#   'complaint': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.'},
#  {'name': 'NGUYEN, OANH',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77089',
#   'complaint_no': '688244',
#   'license_numbers': 'COS20200010645',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent performed an act or practice for which the specialty salon is not licensed.'},
#  {'name': 'NGUYEN, KIMLIEN',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip_code': '79936',
#   'complaint_no': '801094',
#   'license_numbers': 'COS20210012116',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'},
#  {'name': 'NGUYEN, JOHNNY DAT',
#   'city': 'MISSION',
#   'county': 'HIDALGO',
#   'zip_code': '78574',
#   'complaint_no': '797651',
#   'license_numbers': 'COS20210011168',
#   'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, NHO THANH',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78258',
#   'complaint_no': '811760',
#   'license_numbers': 'COS20210014198',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, KEN',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78257',
#   'complaint_no': '1155193',
#   'license_numbers': 'COS20220008308',
#   'complaint': "Respondent's license was revoked upon Respondent's imprisonment in a penitentiary."},
#  {'name': 'NGUYEN, MEJ X',
#   'city': 'PHARR',
#   'county': 'HIDALGO',
#   'zip_code': '78577',
#   'complaint_no': 'Not Licensed',
#   'license_numbers': 'COS20210010069',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology without a license.'},
#  {'name': 'NGUYEN, THI THU HUNG',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77072',
#   'complaint_no': '812471',
#   'license_numbers': 'COS20210011374',
#   'complaint': 'Respondent used a prohibited implement to exfoliate and penetrate the dermis layer of the skin.'},
#  {'name': 'NGUYEN, LOAN HONG ANH',
#   'city': 'COCKRELL HILL',
#   'county': 'DALLAS',
#   'zip_code': '75211',
#   'complaint_no': '757086',
#   'license_numbers': 'COS20220001466',
#   'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instruction; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license."},
#  {'name': 'NGUYEN, HONG VU',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78239',
#   'complaint_no': '787211',
#   'license_numbers': 'COS20210015652',
#   'complaint': "Respondent engaged in gross malpractice; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, LEHUONG',
#   'city': 'MCKINNEY',
#   'county': 'COLLIN',
#   'zip_code': '75070',
#   'complaint_no': '809601',
#   'license_numbers': 'COS20210015023',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, HAI THANH',
#   'city': 'LAREDO',
#   'county': 'WEBB',
#   'zip_code': '78041',
#   'complaint_no': '731397',
#   'license_numbers': 'COS20220001836',
#   'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, CHI',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip_code': '78745',
#   'complaint_no': '794158',
#   'license_numbers': 'COS20210010769',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to post the human trafficking sign; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, THY DINH MINH',
#   'city': 'RICHMOND',
#   'county': 'FORT BEND',
#   'zip_code': '77407',
#   'complaint_no': '791014, 1456306',
#   'license_numbers': 'COS20200012226',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, KATY',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76179',
#   'complaint_no': '789080',
#   'license_numbers': 'COS20200006932',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to remove soiled towels after use on each client.'},
#  {'name': 'NGUYEN, HIEU V',
#   'city': 'LUBBOCK',
#   'county': 'LUBBOCK',
#   'zip_code': '79414',
#   'complaint_no': '1663432',
#   'license_numbers': 'COS20210010477',
#   'complaint': 'Respondent provided other cosmetology services while only holding a manicurist license; Respondent engaged in gross malpractice.'},
#  {'name': 'NGUYEN, ANNA',
#   'city': 'PARKER',
#   'county': 'COLLIN',
#   'zip_code': '75002',
#   'complaint_no': '776928',
#   'license_numbers': 'COS20210005808',
#   'complaint': 'Respondent failed to cooperate with the inspector in the performance of an inspection.'},
#  {'name': 'NGUYEN, NGA T',
#   'city': 'GRAND PRAIRIE',
#   'county': 'TARRANT',
#   'zip_code': '75052',
#   'complaint_no': '733215, 1758833',
#   'license_numbers': 'COS20210008358',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 8 violations; Respondent failed to clean and disinfect all wax pots.'},
#  {'name': 'NGUYEN, THANH',
#   'city': 'FRISCO',
#   'county': 'COLLIN',
#   'zip_code': '75034',
#   'complaint_no': '790672',
#   'license_numbers': 'COS20210004784',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.'},
#  {'name': 'NGUYEN, DAI T',
#   'city': 'HOUSTON',
#   'county': 'Harris',
#   'zip_code': '77034',
#   'complaint_no': '765339',
#   'license_numbers': 'COS20210005027',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area.'},
#  {'name': 'NGUYEN, LONG D',
#   'city': 'SAN SABA',
#   'county': 'SAN SABA',
#   'zip_code': '76877',
#   'complaint_no': '760420, 1620583',
#   'license_numbers': 'COS20210009745',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'},
#  {'name': 'NGUYEN, LUCIE HUONG',
#   'city': 'UVALDE',
#   'county': 'UVALDE',
#   'zip_code': '78801',
#   'complaint_no': '762626, 1811788',
#   'license_numbers': 'COS20210011484',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.'},
#  {'name': 'NGUYEN, CHINH',
#   'city': 'TEMPLE',
#   'county': 'BELL',
#   'zip_code': '76502',
#   'complaint_no': '777067',
#   'license_numbers': 'COS20210011721',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 4 violations; Respondent failed to clean and disinfect manicure tables prior to use for each client.'},
#  {'name': 'NGUYEN, HUNG VU',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77086',
#   'complaint_no': '730692',
#   'license_numbers': 'COS20200006792',
#   'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent's employee failed to have a photograph attached to their license."},
#  {'name': 'NGUYEN, JIMMY',
#   'city': 'ROWLETT',
#   'county': 'DALLAS',
#   'zip_code': '75088',
#   'complaint_no': '796773',
#   'license_numbers': 'COS20200007069',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, NAM',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77025',
#   'complaint_no': '688039',
#   'license_numbers': 'COS20210010530',
#   'complaint': 'Respondents failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to maintain powdered alum, styptic powder, or a cyanoacrylate.'},
#  {'name': 'NGUYEN, DUC',
#   'city': 'ABILENE',
#   'county': 'TAYLOR',
#   'zip_code': '79605',
#   'complaint_no': '758793',
#   'license_numbers': 'COS20200007141',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, THU THAO THI',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78244',
#   'complaint_no': '802892, 1286737',
#   'license_numbers': 'COS20200000839',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology with an expired license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.'},
#  {'name': 'NGUYEN, MINH NHU',
#   'city': 'DALLAS',
#   'county': '',
#   'zip_code': '75243',
#   'complaint_no': '766162, 1502172',
#   'license_numbers': 'COS20210009714',
#   'complaint': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to maintain powdered alum, styptic powder, or a cyanoacrylate."},
#  {'name': 'NGUYEN, DUNG VAN',
#   'city': 'SAULT SAINTE MARIE',
#   'county': 'OUT OF STATE',
#   'zip_code': '49783',
#   'complaint_no': '1202055',
#   'license_numbers': 'COS20210005838',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology without a license.'},
#  {'name': 'NGUYEN, TINH',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77098',
#   'complaint_no': '652914',
#   'license_numbers': 'COS20200010129',
#   'complaint': 'Respondents leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'},
#  {'name': 'NGUYEN, HANG NU THANH',
#   'city': 'PEARLAND',
#   'county': 'BRAZORIA',
#   'zip_code': '77584',
#   'complaint_no': '1642801, 803265, 1704165',
#   'license_numbers': 'COS20210003441',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, LAN N',
#   'city': 'SPRING',
#   'county': 'HARRIS',
#   'zip_code': '77379',
#   'complaint_no': '726731',
#   'license_numbers': 'COS20200009912',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.'},
#  {'name': 'NGUYEN, TIEP HUY',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76244',
#   'complaint_no': '815126',
#   'license_numbers': 'COS20210004018',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging two violations; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, DUNG',
#   'city': 'WICHITA FALLS',
#   'county': 'WICHITA',
#   'zip_code': '76310',
#   'complaint_no': '772680',
#   'license_numbers': 'COS20210000935',
#   'complaint': 'Respondent allowed a licensee to perform a cosmetology service on a client with a contagious condition.'},
#  {'name': 'NGUYEN, THAI VAN',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75040',
#   'complaint_no': '797287, 1187211',
#   'license_numbers': 'COS20210003238',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.'},
#  {'name': 'NGUYEN, THI THAO UYEN',
#   'city': 'CANYON',
#   'county': 'RANDALL',
#   'zip_code': '79015',
#   'complaint_no': '1791395',
#   'license_numbers': 'COS20200005799',
#   'complaint': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.'},
#  {'name': 'NGUYEN, THANH TRONG',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75042',
#   'complaint_no': '1587055',
#   'license_numbers': 'COS20210004209',
#   'complaint': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Applicant has been convicted of a crime that was committed within 5 years of their application; Applicant has a deferred adjudication disposition which makes them unfit to hold a license."},
#  {'name': 'NGUYEN, KHANH V',
#   'city': 'LUBBOCK',
#   'county': 'LUBBOCK',
#   'zip_code': '79413',
#   'complaint_no': '790907, 1149880',
#   'license_numbers': 'COS20200012887',
#   'complaint': 'Respondent failed to clean their hands with soap and water or use a hand sanitizer prior to performing any cosmetology services to ensure a client health and safety.'},
#  {'name': 'NGUYEN, DUC VAN',
#   'city': 'MCALLEN',
#   'county': 'HIDALGO',
#   'zip_code': '78504',
#   'complaint_no': '693169',
#   'license_numbers': 'COS20190014959',
#   'complaint': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging three (3) violations; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent stored chemicals in a restroom accessible to the public.'},
#  {'name': 'NGUYEN, THI HOAN CHAU',
#   'city': 'EDINBURG',
#   'county': 'HIDALGO',
#   'zip_code': '78539',
#   'complaint_no': 'Not Licensed',
#   'license_numbers': 'COS20190011954',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology without a license.'},
#  {'name': 'NGUYEN, PHUCHUNG',
#   'city': 'PLANO',
#   'county': 'COLLIN',
#   'zip_code': '75024',
#   'complaint_no': '686011',
#   'license_numbers': 'COS20200016795',
#   'complaint': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, KIM',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75041',
#   'complaint_no': '723732',
#   'license_numbers': 'COS20200016258',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging two (2) violations; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.'},
#  {'name': 'NGUYEN, HUE VAN',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78247',
#   'complaint_no': '749391',
#   'license_numbers': 'COS20200017028',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used. The Department is charging two (2) violations.'},
#  {'name': 'NGUYEN, HOAI THU T',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip_code': '79925',
#   'complaint_no': '735244',
#   'license_numbers': 'COS20200016091',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, NGHIA T',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76132',
#   'complaint_no': '764444',
#   'license_numbers': 'COS20210001519',
#   'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, HANH THI',
#   'city': 'ORANGE',
#   'county': 'ORANGE',
#   'zip_code': '77630',
#   'complaint_no': '722178',
#   'license_numbers': 'COS20200012575',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging two (2) violations; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to dispose of single use items after each use.'},
#  {'name': 'NGUYEN, HUYEN',
#   'city': 'DALLAS',
#   'county': 'Dallas',
#   'zip_code': '75231',
#   'complaint_no': '686742',
#   'license_numbers': 'COS20200007138',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, Department is charging two (2) violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging two (2) violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging three (3) violations.'},
#  {'name': 'NGUYEN, CHRISTINA M',
#   'city': 'MIDLAND',
#   'county': 'MIDLAND',
#   'zip_code': '79707',
#   'complaint_no': '1522245, 772915',
#   'license_numbers': 'COS20200010817',
#   'complaint': 'Respondent failed to comply with an order previously issued by the Executive Director.'},
#  {'name': 'NGUYEN, THI THIBICH',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip_code': '78415',
#   'complaint_no': '737160',
#   'license_numbers': 'COS20190012445',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology without a license.'},
#  {'name': 'NGUYEN, KIM AN THI',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77008',
#   'complaint_no': '739743',
#   'license_numbers': 'COS20190010554',
#   'complaint': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, VIVIAN KIM',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip_code': '79936',
#   'complaint_no': '805192',
#   'license_numbers': 'COS20200009961',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent was in possession of bottles containing methyl methacrylate monomer.'},
#  {'name': 'NGUYEN, LONG',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip_code': '76002',
#   'complaint_no': 'Not Licensed',
#   'license_numbers': 'COS20200011967',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology without a license.'},
#  {'name': 'NGUYEN, MAI',
#   'city': 'MESQUITE',
#   'county': 'DALLAS',
#   'zip_code': '75150',
#   'complaint_no': '687294',
#   'license_numbers': 'COS20200007264',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly'},
#  {'name': 'NGUYEN, CHINH THI',
#   'city': 'RICHARDSON',
#   'county': 'DALLAS',
#   'zip_code': '75082',
#   'complaint_no': '766787',
#   'license_numbers': 'COS20200009985',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly. This constitutes two (2) violations.'},
#  {'name': 'NGUYEN, THU HA',
#   'city': 'BONHAM',
#   'county': 'FANNIN',
#   'zip_code': '75418',
#   'complaint_no': '789513',
#   'license_numbers': 'COS20200014601',
#   'complaint': 'Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client'},
#  {'name': 'NGUYEN, HA THI THU',
#   'city': 'DICKINSON',
#   'county': 'GALVESTON',
#   'zip_code': '77539',
#   'complaint_no': '784491',
#   'license_numbers': 'COS20200015200',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'},
#  {'name': 'NGUYEN, CHAU',
#   'city': 'LEWISVILLE',
#   'county': 'DENTON',
#   'zip_code': '75056',
#   'complaint_no': '777577',
#   'license_numbers': 'COS20210002574',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to have chairs made of or covered in a non-porous material so that they can be disinfected.'},
#  {'name': 'NGUYEN, HUNG VU',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77086',
#   'complaint_no': '730692',
#   'license_numbers': 'COS20190011025',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to discard single use implements after each use; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.'},
#  {'name': 'NGUYEN, MIMI PHAM',
#   'city': 'KATY',
#   'county': 'HARRIS',
#   'zip_code': '77449',
#   'complaint_no': '784210',
#   'license_numbers': 'COS20190010072',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.'},
#  {'name': 'NGUYEN, HA',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip_code': '76017',
#   'complaint_no': '764888',
#   'license_numbers': 'COS20190016762',
#   'complaint': 'Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.'},
#  {'name': 'NGUYEN, THAO HONG',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78238',
#   'complaint_no': '799926, 1753491',
#   'license_numbers': 'COS20200010387',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, CINDY',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip_code': '78414',
#   'complaint_no': '806232, 1260359, 1280071',
#   'license_numbers': 'COS20200010502',
#   'complaint': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.'},
#  {'name': 'NGUYEN, CHAU KHANH LINH',
#   'city': 'MONTGOMERY',
#   'county': 'OUT OF STATE',
#   'zip_code': '36116',
#   'complaint_no': '1764073',
#   'license_numbers': 'COS20190008104',
#   'complaint': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.'},
#  {'name': 'NGUYEN, TRANG T',
#   'city': 'SEGUIN',
#   'county': 'GUADALUPE',
#   'zip_code': '78155',
#   'complaint_no': '748483',
#   'license_numbers': 'COS20200010511',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.'},
#  {'name': 'NGUYEN, DUNG MINH',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77066',
#   'complaint_no': '785878',
#   'license_numbers': 'COS20200004202',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, YEN NHI THI',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip_code': '78717',
#   'complaint_no': '763645',
#   'license_numbers': 'COS20190004199',
#   'complaint': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.'},
#  {'name': 'NGUYEN, JOHNNY DAT',
#   'city': 'MISSION',
#   'county': 'HIDALGO',
#   'zip_code': '78574',
#   'complaint_no': '797651',
#   'license_numbers': 'COS20200000101',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.'},
#  {'name': 'NGUYEN, KELLY PHUONG N',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip_code': '78413',
#   'complaint_no': '751553',
#   'license_numbers': 'COS20200011664',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon.'},
#  {'name': 'NGUYEN, NGA THU',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77038',
#   'complaint_no': '737176',
#   'license_numbers': 'COS20200010961',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.'},
#  {'name': 'NGUYEN, IVY',
#   'city': 'SHERMAN',
#   'county': 'GRAYSON',
#   'zip_code': '75092',
#   'complaint_no': '772886',
#   'license_numbers': 'COS20200008858',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.'},
#  {'name': 'NGUYEN, DIEMTRINH T',
#   'city': 'CARROLLTON',
#   'county': 'DALLAS',
#   'zip_code': '75010',
#   'complaint_no': '736591',
#   'license_numbers': 'COS20200008859',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, HUAN CAO',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78229',
#   'complaint_no': '786237',
#   'license_numbers': 'COS20200009732',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.'},
#  {'name': 'NGUYEN, THOA KIM',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip_code': '78413',
#   'complaint_no': '758361',
#   'license_numbers': 'COS20200006548',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.'},
#  {'name': 'NGUYEN, TONY',
#   'city': 'MARBLE FALLS',
#   'county': 'BURNET',
#   'zip_code': '78654',
#   'complaint_no': 'Not Licensed',
#   'license_numbers': 'COS20200009605',
#   'complaint': 'Respondent performed or attempted to perform a practice of cosmetology without a license.'},
#  {'name': 'NGUYEN, HIEN',
#   'city': 'LONGVIEW',
#   'county': 'GREGG',
#   'zip_code': '75605',
#   'complaint_no': '801727',
#   'license_numbers': 'COS20190016479',
#   'complaint': 'Respondent failed to clean and disinfect all wax pots.'},
#  {'name': 'NGUYEN, NGOC TRAM',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76137',
#   'complaint_no': '712767',
#   'license_numbers': 'COS20190012148',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, TRAN NAM',
#   'city': 'CANYON',
#   'county': 'RANDALL',
#   'zip_code': '79015',
#   'complaint_no': '733729',
#   'license_numbers': 'COS20190010318',
#   'complaint': 'Respondent failed to cooperate with the inspector in the performance of an inspection.'},
#  {'name': 'NGUYEN, PHILLIP',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip_code': '79912',
#   'complaint_no': '692372',
#   'license_numbers': 'COS20190014688',
#   'complaint': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.'},
#  {'name': 'NGUYEN, THUY T',
#   'city': 'CARROLLTON',
#   'county': 'DALLAS',
#   'zip_code': '75007',
#   'complaint_no': '794091',
#   'license_numbers': 'COS20190004016',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.'},
#  {'name': 'NGUYEN, TRACY',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76137',
#   'complaint_no': '746762',
#   'license_numbers': 'COS20190016499',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, LE PHUC',
#   'city': 'SACHSE',
#   'county': 'COLLIN',
#   'zip_code': '75048',
#   'complaint_no': '739879',
#   'license_numbers': 'COS20200006146',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, HAI MINH',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip_code': '79936',
#   'complaint_no': '726039, 1110890',
#   'license_numbers': 'COS20190016549',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, TUYET',
#   'city': 'GRAND PRAIRIE',
#   'county': 'DALLAS',
#   'zip_code': '75052',
#   'complaint_no': '774330, 1658860',
#   'license_numbers': 'COS20190017217',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, BA VAN',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip_code': '76001',
#   'complaint_no': '676940',
#   'license_numbers': 'COS20190016854',
#   'complaint': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.'},
#  {'name': 'NGUYEN, LAN THANH',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip_code': '75216',
#   'complaint_no': '766697',
#   'license_numbers': 'COS20190017175',
#   'complaint': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.'},
#  {'name': 'NGUYEN, PHUOC BA',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78250',
#   'complaint_no': '788725, 1552617',
#   'license_numbers': 'COS20190013017',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, LINH THUY KIEU',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75044',
#   'complaint_no': '795480, 1700076',
#   'license_numbers': 'COS20190016161',
#   'complaint': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.'},
#  {'name': 'NGUYEN, TONY MINH',
#   'city': 'MARBLE FALLS',
#   'county': 'BURNET',
#   'zip_code': '78654',
#   'complaint_no': '791638, 1124706',
#   'license_numbers': 'COS20200000652',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, THANH',
#   'city': 'FRISCO',
#   'county': 'COLLIN',
#   'zip_code': '75034',
#   'complaint_no': '790672',
#   'license_numbers': 'COS20190007906',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, HIEN THI MINH',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77083',
#   'complaint_no': '795179',
#   'license_numbers': 'COS20190003737',
#   'complaint': 'Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.'},
#  {'name': 'NGUYEN, VAN NGOC THAO',
#   'city': 'WAXAHACHIE',
#   'county': 'ELLIS',
#   'zip_code': '75165',
#   'complaint_no': 'Not Licensed',
#   'license_numbers': 'COS20190006118',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.'},
#  {'name': 'NGUYEN, TAM THANH',
#   'city': 'SAN ANGELO',
#   'county': 'TOM GREEN',
#   'zip_code': '76904',
#   'complaint_no': '1163702',
#   'license_numbers': 'COS20200002642',
#   'complaint': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary."},
#  {'name': 'NGUYEN, ANDY HUU',
#   'city': 'HURST',
#   'county': 'TARRANT',
#   'zip_code': '76053',
#   'complaint_no': '776906, 1189873',
#   'license_numbers': 'COS20190009211',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.'},
#  {'name': 'NGUYEN, CUONG HULL',
#   'city': 'GRAND PRAIRIE',
#   'county': 'TARRANT',
#   'zip_code': '75052',
#   'complaint_no': '767705, 1094245',
#   'license_numbers': 'COS20190010611',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, NANCY HOA',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75044',
#   'complaint_no': '785647, 1121812',
#   'license_numbers': 'COS20190010665',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.'},
#  {'name': 'NGUYEN, THOA THI KIM',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip_code': '78411',
#   'complaint_no': '739510',
#   'license_numbers': 'COS20190001932',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.'},
#  {'name': 'NGUYEN, TRANG',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75041',
#   'complaint_no': '693311',
#   'license_numbers': 'COS20190014576',
#   'complaint': 'Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.'},
#  {'name': 'NGUYEN, THONG VAN',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip_code': '79912',
#   'complaint_no': '750663',
#   'license_numbers': 'COS20190001897',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, TUAN',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip_code': '75237',
#   'complaint_no': '783281',
#   'license_numbers': 'COS20190009239',
#   'complaint': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant."},
#  {'name': 'NGUYEN, LYNDA',
#   'city': 'KATY',
#   'county': 'HARRIS',
#   'zip_code': '77449',
#   'complaint_no': '781789',
#   'license_numbers': 'COS20190009484',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.'},
#  {'name': 'NGUYEN, CATHY H',
#   'city': 'ROUND ROCK',
#   'county': 'WILLIAMSON',
#   'zip_code': '78665',
#   'complaint_no': 'NGUYEN, JOHNNY VAN',
#   'license_numbers': 'ROUND ROCK',
#   'complaint': 'WILLIAMSON'},
#  {'name': 'NGUYEN, PAMELA DAN',
#   'city': 'SEGUIN',
#   'county': 'GUADALUPE',
#   'zip_code': '78155',
#   'complaint_no': '747589',
#   'license_numbers': 'COS20190011923',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.'},
#  {'name': 'NGUYEN, SON QUOC',
#   'city': 'HILLSBORO',
#   'county': 'HILL',
#   'zip_code': '76645',
#   'complaint_no': '772305, 1240974',
#   'license_numbers': 'COS20190005539',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, KIM',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip_code': '75240',
#   'complaint_no': '786602',
#   'license_numbers': 'COS20190010176',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, THAI VAN',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip_code': '75040',
#   'complaint_no': '797287, 1187211',
#   'license_numbers': 'COS20190010397',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, HANH THI',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77049',
#   'complaint_no': '786707',
#   'license_numbers': 'COS20190011044',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.'},
#  {'name': 'NGUYEN, DIEP THI NGOC',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77067',
#   'complaint_no': '760528',
#   'license_numbers': 'COS20190003373',
#   'complaint': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.'},
#  {'name': 'NGUYEN, CASEY',
#   'city': 'CYPRESS',
#   'county': 'HARRIS',
#   'zip_code': '77429',
#   'complaint_no': '790137',
#   'license_numbers': 'COS20190010299',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, ANTHONY VAN',
#   'city': 'HALTOM CITY',
#   'county': 'TARRANT',
#   'zip_code': '76117',
#   'complaint_no': '750159',
#   'license_numbers': 'COS20190013988',
#   'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, CHRISTINA D',
#   'city': 'PORT ARTHUR',
#   'county': 'JEFFERSON',
#   'zip_code': '77642',
#   'complaint_no': '716740',
#   'license_numbers': 'COS20190012652',
#   'complaint': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, PHUONG T',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77083',
#   'complaint_no': '748459',
#   'license_numbers': 'COS20180015395',
#   'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.'},
#  {'name': 'NGUYEN, KENNY',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip_code': '75232',
#   'complaint_no': '75611',
#   'license_numbers': 'COS20190010057',
#   'complaint': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'},
#  {'name': 'NGUYEN, THAO (MINH THAO',
#   'city': 'LOCKHART',
#   'county': 'CALDWELL',
#   'zip_code': '78644',
#   'complaint_no': '785264',
#   'license_numbers': 'COS20190010254',
#   'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, KENNY',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip_code': '75232',
#   'complaint_no': '756711',
#   'license_numbers': 'COS20190000183',
#   'complaint': 'Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'},
#  {'name': 'NGUYEN, BA VAN',
#   'city': 'MANSFIELD',
#   'county': 'TARRANT',
#   'zip_code': '76063',
#   'complaint_no': '720112',
#   'license_numbers': 'COS20190010606',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, KHUYEN THI',
#   'city': 'HALTOM CITY',
#   'county': 'TARRANT',
#   'zip_code': '76117',
#   'complaint_no': '771681, 1442799',
#   'license_numbers': 'COS20190010961',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, SON DANG',
#   'city': 'FOREST HILL',
#   'county': 'TARRANT',
#   'zip_code': '76119',
#   'complaint_no': '720091, 1195752',
#   'license_numbers': 'COS20190010635',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, TUYEN THANH',
#   'city': 'AUBREY',
#   'county': 'DENTON',
#   'zip_code': '76227',
#   'complaint_no': '792178, 1468619, 1410422',
#   'license_numbers': 'COS20190014566',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.'},
#  {'name': 'NGUYEN, STEVEN THAI',
#   'city': 'CORSICANA',
#   'county': 'NAVARRO',
#   'zip_code': '75110',
#   'complaint_no': '779635',
#   'license_numbers': 'COS20190010869',
#   'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'},
#  {'name': 'NGUYEN, CY VAN',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77007',
#   'complaint_no': '765590',
#   'license_numbers': 'COS20190007921',
#   'complaint': 'Respondent operated a cosmetology salon without the appropriate license.'},
#  {'name': 'NGUYEN, KIM NGAN THI',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77084',
#   'complaint_no': '1434311',
#   'license_numbers': 'COS2009004238D',
#   'complaint': 'Respondent interfered with a Department inspection of the salon.'}]

# %% [markdown]
# ### Save that to a CSV named `output.csv`
#
# The dataframe should look something like...
#
# |index|name|city|county|zip_code|complaint_no|license_numbers|complaint|
# |---|---|---|---|---|---|---|---|
# |0|NGUYEN, THANH|FRISCO|COLLIN|75034|COS20210004784|790672|Respondent failed to clean and sanitize whirlp...|
# |1|NGUYEN, LONG D|SAN SABA|SAN SABA|76877|COS20210009745|760420, 1620583|Respondent failed to keep a record of the date...|
#
#
# - *Tip: If you send a list of dictionaries to `pd.DataFrame(...)`, it will create a dataframe out of that list!*

# %%
df = pd.DataFrame(records)
df.head()
# Out:
#                       name        city   county zip_code complaint_no  \
# 0            NGUYEN, MAI T      AUSTIN   TRAVIS    78717       750076
# 1          NGUYEN, HUNG VU     HOUSTON   HARRIS    77086       763912
# 2  NGUYEN, MINH HIEN LUONG  CARROLLTON   DALLAS    75007       777932
# 3         NGUYEN, PHUONG T       PLANO   COLLIN    75023       766293
# 4      NGUYEN, STEVEN MANH  FORT WORTH  TARRANT    76244       773318
#
#   license_numbers                                          complaint
# 0  COS20220000853  Respondent failed to clean, disinfect, and ste...
# 1  COS20200013887  Respondent failed to keep floors, walls, ceili...
# 2  COS20210010437  Respondent failed to clean and sanitize whirlp...
# 3  COS20210014779  Respondent failed to keep a record of the date...
# 4  COS20200015190  Respondent leased space in a salon to an indiv...

# %%
df.to_csv("output.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('output.csv').head()
# Out:
#                       name        city   county  zip_code complaint_no  \
# 0            NGUYEN, MAI T      AUSTIN   TRAVIS     78717       750076
# 1          NGUYEN, HUNG VU     HOUSTON   HARRIS     77086       763912
# 2  NGUYEN, MINH HIEN LUONG  CARROLLTON   DALLAS     75007       777932
# 3         NGUYEN, PHUONG T       PLANO   COLLIN     75023       766293
# 4      NGUYEN, STEVEN MANH  FORT WORTH  TARRANT     76244       773318
#
#   license_numbers                                          complaint
# 0  COS20220000853  Respondent failed to clean, disinfect, and ste...
# 1  COS20200013887  Respondent failed to keep floors, walls, ceili...
# 2  COS20210010437  Respondent failed to clean and sanitize whirlp...
# 3  COS20210014779  Respondent failed to keep a record of the date...
# 4  COS20200015190  Respondent leased space in a salon to an indiv...
